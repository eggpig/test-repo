# %% [markdown]
# <span id="mulu"><font face="黑体" size=6>本章目录</font></span>
# * [第十五讲 Pandas 模块](#9)
#     * [15.1 引言](#15.1)
#     * [15.2 Series 对象 —— 序列](#15.2)
#         * [15.2.1 创建 Series 对象](#15.2.1)
#         * [15.2.2 访问 Series 对象](#15.2.2)
#         * [15.2.3 修改 Series 对象](#15.2.3)
#         * [15.2.4 添加 Series 对象](#15.2.4)
#         * [15.2.5 删除 Series 对象](#15.2.5)
#     * [15.3 DataFrame 对象 —— 数据帧](#15.3)
#         * [15.3.1 创建 DataFrame 对象](#15.3.1)
#         * [15.3.2 访问 DataFrame 对象](#15.3.2)
#         * [15.3.3 修改 DataFrame 对象](#15.3.3)
#         * [15.3.4 添加行列](#15.3.4)
#         * [15.3.5 删除行列](#15.3.5)
#     * [15.4 Pandas 文件操作](#15.4)
#         * [15.4.1 csv 文件](#15.4.1)
#         * [15.4.2 excel 文件](#15.4.2)
#         * [15.4.3 Json 文件](#15.4.3)
#     * [15.5 Pandas 统计分析](#15.5)
#         * [15.5.1 数据统计](#15.5.1)
#         * [15.5.2 图形可视化](#15.5.2)

# %% [markdown]
# # 第15讲 Pandas模块

# %% [markdown]
# ## <font size=5><span id="15.1"> 15.1 引言</span></font>

# %% [markdown]
# <table>
#     <tr>
#         <td ><center><img src='images\chapter15\pandas01.jpg' width=400> 图1  萌萌哒 </center></td>
#         <td ><center><img src='images\chapter15\pandas02.jpg' width=300> 图2 powerful</center></td>
#     </tr>
# </table>
#
# - Pandas 是基于NumPy 的一种工具，该工具是为了解决数据分析任务而创建的。
# - Pandas 纳入了大量库和一些标准的数据模型，提供了高效地操作大型数据集所需的工具。
# - Pandas提供了大量能使我们快速便捷地处理数据的函数和方法。
#
# 两种Pandas的对象：
# - Series 序列
# - DataFrame 数据帧

# %% [markdown]
# Pandas 做够胜任的一些事情:
# - 在浮点和非浮点数据中轻松处理`缺失数据`（表示为NaN）。
# - 大小可变性：可以从DataFrame和更高维度的对象中`插入和删除`。
# - 自动和显式`数据对齐`：对象可以明确地与一组标签对齐，或者用户可以简单地忽略标签，让Series，DataFrame等在计算中自动对齐数据
# - 强大，灵活的`组（group by）`功能，可对数据集执行拆分应用组合操作，用于聚合和转换数据。
# - `轻松`将其他Python和NumPy数据结构中的不规则，不同索引数据转换为DataFrame对象。
# - 基于智能标签的`切片，花式索引`和`子集`大数据集。
# - 直观`合并`和`加入`数据集。
# - 灵活的`重塑`和数据集的旋转。
# - `轴的分层`标记（每个刻度可能有多个标签）。
# - 强大的IO工具，用于从`平面文件`（CSV和分隔）、Excel文件、数据库以及能从超快的`HDF5格式`<https://baike.baidu.com/item/HDF/1256312?fr=aladdin>中保存或加载数据。
# - 特定`时间序列`功能：日期范围生成和频率转换、移动窗口统计、移动窗口线性回归、日期转换和滞后等。

# %% [markdown]
# - 数据结构
#
# | 维数 |	名称	|描述 |
# -|-|-
# |1|	Series	|可以看做有标签（默认是整数序列RangeIndex；可以重复）的一维数组（同类型）。<br>是scalars的集合，同时也是DataFrame的元素。|
# |2|	DataFrame	|一般是二维标签，尺寸可变的表格结构，具有潜在的异质型列。|

# %% [markdown]
# #### 导入基本模块

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## <font size=5><span id="15.2"> 15.2 Series 对象 —— 序列</span></font>
#
# - 初识 Series 对象 —— 序列
#     - pandas 中基本对象
#     - 一维数据结构
#     - 由相同元素类型构成
#     - 有列表、数组和字典的属性
# <img src="images\chapter15\series.jpg">

# %% [markdown]
# ### <font size=5><span id="15.2.1"> 15.2.1 创建 Series 对象</span></font>
# - 基本语法
#
# ```python
# >>> s = pd.Series(data=None, index=None, dtype=None, name=None, copy=False, fastpath=False)
# ```
#     或
# ```python
# >>> s = pd.Series(data)
# ```
#
# - 参数说明
#     - `data` 可为多种类型，如
#         - Python 字典
#         - ndarray
#         - 标量值
#         - 空列表
#     - `index` 索引列表
#         - 缺省时，index 为连续整数索引
#
#
#
# - 关键属性
#     - 索引 index
#     - 名字 name
#     - 值 values
#     - 类型 dtype

# %% [markdown]
# ### <font size=5><span id="15.2.2"> 15.2.2 访问 Series 对象</span></font>

# %% [markdown]
# #### （1）直接访问
# - 通过下标访问
# - 通过索引访问
# - 通过下标切片访问
# - 通过索引切片访问
# - 通过布尔掩码访问

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.randint(1,99,6), index=['a', 'b', 'c', 'd', 'e', 'f'])
s
# Out:
# a    80
# b    67
# c    51
# d    29
# e    95
# f    24
# dtype: int32

# %%
s.iloc[0]
# Out:
# 80

# %% [markdown]
# #### （2）通过 `.loc[]` 方式访问，基于索引 index
# - .loc[] 查询方式和 [] 相似
# - 使用索引
# - 不能使用下标

# %%
s.loc['a']
# Out:
# 23

# %% [markdown]
# #### （3）通过 `.iloc[]` 方式访问，基于下标
#
# - .iloc[] 查询方式和 [] 相似
# - 使用下标
# - 不能使用索引

# %%
s.iloc[0]
# Out:
# 80

# %% [markdown]
# ### <font size=5><span id="15.2.3"> 15.2.3 修改 Series 对象</span></font>

# %% [markdown]
# #### （1）修改值 —— 访问右端方式

# %%
s
# Out:
# a    23
# b    90
# c    66
# d    63
# e    19
# f    77
# dtype: int64

# %%
s['a'] = 10

# %% [markdown]
# #### （2）修改值 —— 函数方式
# - 函数语法
#
# ```python
# >>> pd.Series.replace(to_replace=None, value=None, inplace=False)
# ```
# - 参数说明
#     - to_replace：拟修改的值，可以为列表
#     - value：    修改后的值，可以为列表，与 to_repalce 要匹配
#     - inplace：  是否在原地修改

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
print(s)
s.replace([10, 20], [90, 100])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# a     90
# b    100
# c     30
# d     40
# e     50
# dtype: int64

# %% [markdown]
# #### （3）修改索引 index —— 直接方式
#
# - 注意 —— index 类似于 tuple，不支持元素、切片修改

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
s.index = ['A', 'B', 'C', 'D', 'E']
s
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# #### （4）修改索引 index —— rename 函数方式
#
# - 语法
#
#     ```python
#     >>> pd.Series.rename(index=None, level = None, inplace = False)
#     ```
#
# - 参数说明
#     - index：dict，可以部分修改；
#     - level：多重索引时，可以指定修改哪一重，从0开始递增；
#     - inplace：是否原地修改。

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
s.rename(index={'a':'A'}, inplace=True)
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s = pd.Series([10, 20, 30, 40, 50])
s.rename(index=lambda x:x**2, inplace=True)
s
# Out:
# 0     10
# 1     20
# 4     30
# 9     40
# 16    50
# dtype: int64

# %% [markdown]
# #### （5）重置索引 index —— reindex 函数方式
# - 语法
#     ```python
#     >>> pd.Series.reindex(index=None, **kwargs)
#     ```
# - 参数说明
#     - index：类似于数组，可选，避免重复索引
#     - kwargs：关键字参数

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
print(s)
s = s.reindex(['g', 'f', 'e', 'd', 'c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# g     NaN
# f     NaN
# e    50.0
# d    40.0
# c    30.0
# dtype: float64

# %% [markdown]
# ### <font size=5><span id="15.2.4"> 15.2.4 添加 Series 对象</span></font>

# %% [markdown]
# #### （1）字典方式 —— 增单个元素

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
print(s)
s['f'] = 60
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %% [markdown]
# #### （2）函数方式 —— 增多个元素
#
# - 语法
#     ```python
#     >>> pd.Series.append(to_append, ignore_index=False, verify_integrity=False)
#     ```
#
# - 参数说明
#     - to_append: 拟添加 series 或多个 Series 构成的列表
#     - ignore_index：False-保留原有索引，True-清除所有索引，生成默认数值索引
#     - verify_integrity：为 True 时，如果to_append索引与当前索引有重复，则报错

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
s1 = pd.Series([60, 70], ['f', 'g'])
s = s.append(s1)
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64
# /var/folders/dx/qnk8l5xn4893gm1j1d25prjh0000gn/T/ipykernel_34709/3801602295.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s = s.append(s1)

# %% [markdown]
# ### <font size=5><span id="15.2.5"> 15.2.5 删除 Series 对象</span></font>

# %% [markdown]
# #### （1）直接方式 —— 删单个元素

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
del s['a']
print(s)
# Out:
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# #### （2）函数方式 —— 删除多元素
#
# - 基本语法
#
# ```python
# >>> Series.drop(labels, level=None, inplace=False)
# ```
#
# - 参数说明
#     - labels：索引，单索引或索引的列表；
#     - level：多重索引需要设置；
#     - inplace：是否本地修改。

# %%
s = pd.Series([10, 20, 30, 40, 50], ['a', 'b', 'c', 'd', 'e'])
s = s.drop(['a','b'])
print(s)
# Out:
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# #### 课堂小练习：
# - 建立一个series对象scores，名称为"语文",存放若干学生的“语文”成绩
# - 人名分别为，Aladin, Bomb, Christian, Daniel
# - 分数分别为：86,92,79,45
# - 增加一个人叫：Epson，分数为98
# - 删除一个分数不及格的人

# %% [markdown]
# ## <font size=5><span id="15.3"> 15.3 DataFrame 对象 —— 数据帧</span></font>
#
#
# - 基本说明
#
#     - DataFrame 是二维带标记数据结构
#     - 有行和列标记，分别是 index 和 columns
#     - 各列可以是不同类型的数据
# <img src="images\chapter15\dataframe.jpg" width=400>
#
# - 相似东东
#
#     - Excel 表格
#     - SQL 表
#     - 由列标记指向 Series 对象的字典

# %% [markdown]
# ### <font size=5><span id="15.3.1"> 15.3.1 创建 DataFrame 对象</span></font>
# - 基本语法
#
# ```python
# >>> df = pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)
# ```
#
#
# - 参数说明
#
#     - `data` 可为多种类型 —— numpy 数组(良好结构且同质)、Python 字典、DataFrame 字典、python 列表、标量值
#     - `index` 索引列表
#         - 缺省时，index 为连续整数索引
#     - `columns` 类似于索引的列标记
#         - 缺省时，columns 为连续整数索引
#
#
# - 关键属性
#     - 索引 index
#     - 列  columns
#     - 值  values
#     - 类型 dtypes

# %%
df = pd.DataFrame(np.random.randn(8, 4))
df
# Out:
#           0         1         2         3
# 0  0.484269  0.731143 -0.634977  0.640799
# 1  0.066944  0.525737  2.103027  0.665102
# 2 -0.084558 -0.854708  0.586789 -0.418641
# 3  0.408930 -0.070109 -1.372662 -1.235450
# 4  0.601624  0.628070 -0.511482  1.652399
# 5 -0.702962  0.446973  0.361464 -0.219936
# 6  0.974321  1.146579 -1.683421  0.893636
# 7 -2.886299  0.492124  1.037220  0.076133

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %% [markdown]
# ### <font size=5><span id="15.3.2"> 15.3.2 访问 DataFrame 对象</span></font>

# %% [markdown]
# #### （1）首尾访问
#
# ```python
# >>> pd.DataFrame.head(n=5)
# ```
#
# ```python
# >>> pd.DataFrame.tail(n=5)
# ```
#
# - 参数说明
#     - n 行数，缺省取 5

# %% [markdown]
# #### （2）属性访问
#
# - 索引 index
# - 列 columns
# - 值 values
# - 描述 describe()

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)

# %%
print(df.index, '\n')
print(df.columns, '\n')
print(df.values, '\n')
print(df.describe(), '\n')
# Out:
# Index(['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei'], dtype='object')
#
# Index(['Math', 'Language', 'Economy'], dtype='object')
#
# [[99 85 91]
#  [87 91 88]
#  [66 75 76]
#  [43 90 30]
#  [80 63 92]
#  [94 95 79]]
#
#             Math   Language    Economy
# count   6.000000   6.000000   6.000000
# mean   78.166667  83.166667  76.000000
# std    20.740460  12.040210  23.452079
# min    43.000000  63.000000  30.000000
# 25%    69.500000  77.500000  76.750000
# 50%    83.500000  87.500000  83.500000
# 75%    92.250000  90.750000  90.250000
# max    99.000000  95.000000  92.000000

# %% [markdown]
# #### （3）直接列访问
#
# - 访问方式
#
# ```python
# >>> pd.DataFrame[col_label]
# ```
#
#
# - 参数
#     - col_label 列标记
#
#
# - 返回：序列
#
#
# - 注意：也可用双层方括号，返回子数据帧
#
#
# ```python
# >>> pd.DataFrame[[col_label]]
# ```

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %%
s = df['Math']
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### （4）直接行访问
# ```python
# >>> pd.DataFrame[i1:i2]
# ```
# - 参数
#     - i1:i2 行下标切片，左闭右开
# - 返回：子数据帧

# %%
df[0:3]
# Out:
#       Math  Language  Economy
# Jim     99        85       91
# Jack    87        91       88
# Lucy    66        75       76

# %% [markdown]
# #### （5）`.loc[]` 索引访问方式
# 在DataFrame中，.loc[] 与 [] 有区别
#
# - DataFrame 有两维，每一维都和 Series 的 `.loc[]` 用法相同；
# - Series有四种方式，所以DataFrame有**16种**方式;
# - 可以缺省后面维度，默认补全为 ':' 。

# %%
df.loc['Jim']
# Out:
# Math        99
# Language    85
# Economy     91
# Name: Jim, dtype: int64

# %% [markdown]
# #### （6）`.iloc[]`，下标方式访问
# - 注意：只用下标，不用索引
#     - DataFrame 有两维，每一维都和 Series 的 `.iloc[]` 用法相同；
#     - Series有四种方式，所以DataFrame有**16**种方式；
#     - 可以缺省后面维度，默认补全为 `':'` 。

# %%
df.iloc[0]
# Out:
# Math        99
# Language    85
# Economy     91
# Name: Jim, dtype: int64

# %% [markdown]
# ### <font size=5><span id="15.3.3"> 15.3.3 修改 DataFrame 对象</span></font>

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %% [markdown]
# #### （1）修改值 —— 访问右端赋值方式
# - .loc[]方法确保原地修改

# %%
df.loc['Jim', 'Math'] = 100
df
# Out:
#             Math  Language  Economy
# Jim          100        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %% [markdown]
# #### （2）修改值 —— 函数批量方式
# - 函数语法
#
# ```python
# >>> pd.DataFrame.replace(to_replace=None, value=None, inplace=False)
# ```
# - 参数说明
#     - to_replace：拟修改的值，可以为列表
#     - value：    修改后的值，可以为列表，与 to_repalce 要匹配
#     - inplace：  是否在原地修改

# %%
df = df.replace(to_replace=88, value=90)   # to_replace=91
df
# Out:
#             Math  Language  Economy
# Jim          100        85       91
# Jack          87        91       90
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %% [markdown]
# #### （3）修改索引 —— 直接方式
#
# - 注意，索引类似于tuple
#     - 必须完整修改
#     - 不能部分修改

# %%
df.index = ['吉姆', '杰克', '露西', '莉莉', '韩梅梅', '李雷']
df.columns = ['数学', '语言', '经济学']
df
# Out:
#      数学  语言  经济学
# 吉姆   99  85   91
# 杰克   87  91   88
# 露西   66  75   76
# 莉莉   43  90   30
# 韩梅梅  80  63   92
# 李雷   94  95   79

# %% [markdown]
# #### （4）修改索引 —— 函数方式
#
# - 语法
#
#     ```python
#     >>> pd.DataFrame.rename(index=None, columns=None,  level=None, inplace=False)
#     ```
#
# - 参数说明
#     - index：dict，可以部分修改
#     - columns：dict，可以部分修改
#     - level：多重索引时，可以指定修改哪一重（暂不用）
#     - inplace：是否原地修改。

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %%
df = df.rename(index={'Jim':'吉姆'})
df
# Out:
#             Math  Language  Economy
# 吉姆            99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %% [markdown]
# ### <font size=5><span id="15.3.4"> 15.3.4 添加行列</span></font>

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df

# %% [markdown]
# #### （1）加单行 —— 字典方式

# %%
df.loc['Uncle Wang'] = [90, 76, 80]
df
# Out:
#             Math  Language  Economy
# 吉姆            99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79
# Uncle Wang    90        76       80

# %% [markdown]
# #### （2）增加多行 —— 函数方式
#
# - 语法
#     ```python
#     >>> pd.concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False,
#                   keys=None, levels=None, names=None, verify_integrity=False, sort=None, copy=True)
#     ```
#
#
# - 参数说明
#     - objs: 序列(Series)、数据帧(DataFrame)、面板(Panel)等对象为元素的列表、字典等系列(sequence)
#     - axis： 0:沿行增加, 1：沿列增加，缺省为 0
#     - 其它 (多数情况不须考虑，自学)
#
#
# - 注意事项
#     - 列索引 columns 要求一致
#     - 行索引 index 避免重复

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df1 = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df2 = pd.DataFrame({"Math":85, "Language":78, "Economy": 95}, index = ['Uncle Wang'])

# %%
print(df1)
print(df2)
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79
#             Math  Language  Economy
# Uncle Wang    85        78       95

# %%
df = pd.concat([df1, df2], axis=0)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79
# Uncle Wang    85        78       95

# %% [markdown]
# #### （3）增加单列 —— 字典方式

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %%
df['Physics'] = [67, 90, 67, 87, 90, 82]
df
# Out:
#             Math  Language  Economy  Physics
# Jim           99        85       91       67
# Jack          87        91       88       90
# Lucy          66        75       76       67
# Lily          43        90       30       87
# Han Meimei    80        63       92       90
# Li Lei        94        95       79       82

# %% [markdown]
# #### （4）增加多列 —— 函数方式
#
# - 语法
#     ```python
#     >>> pd.concat(objs, axis=1, join='outer', join_axes=None, ignore_index=False,
#                   keys=None, levels=None, names=None, verify_integrity=False, sort=None, copy=True)
#     ```
#
#
# - 参数说明
#     - objs: 序列(Series)、数据帧(DataFrame)、面板(Panel)等对象为元素的列表、字典等系列(sequence)
#     - axis： 0:沿行增加, <font color='red'>1：沿列增加</font>，缺省为 0
#     - 其它 (多数情况不须考虑，自学)
#
#
# - 注意事项
#     - 列索引 columns 要求一致
#     - 行索引 index 避免重复

# %% [markdown]
# ### <font size=5><span id="15.3.5"> 15.3.5 删除行列</span></font>

# %% [markdown]
# #### （1）删除多行 —— drop 函数方式
#
#
# - 语法
#     ```python
#     >>> pd.DataFrame.drop(self, labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#     ```
#
#
# - 参数说明
#     - labels: 单个标记、或标记列表，存放拟删除的行或列标记
#     - axis： {0 or 'index', 1 or 'columns'}, default 0，是否删除行或列标记
#     - inplace：是否本地修改
#     - 其它 (多数情况不须考虑，自学)

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df
# Out:
#             Math  Language  Economy
# Jim           99        85       91
# Jack          87        91       88
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %%
df.drop(index=['Jim','Jack'])
# Out:
#             Math  Language  Economy
# Lucy          66        75       76
# Lily          43        90       30
# Han Meimei    80        63       92
# Li Lei        94        95       79

# %% [markdown]
# #### （2）删除单列 —— 字典操作

# %%
del df['Math']
df
# Out:
#             Language  Economy
# Jim               85       91
# Jack              91       88
# Lucy              75       76
# Lily              90       30
# Han Meimei        63       92
# Li Lei            95       79

# %% [markdown]
# #### （3）删除多列 —— 函数方式
#
#
# - 语法
#     ```python
#     >>> pd.DataFrame.drop(self, labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#     ```
#
#
# - 参数说明
#     - labels: 单个标记、或标记列表，存放拟删除的行或列标记
#     - axis： 1 或 'columns', 删除列标记
#     - inplace：是否本地修改
#     - 其它 (多数情况不须考虑，自学)

# %%
names = ['Jim', 'Jack', 'Lucy', 'Lily', 'Han Meimei', 'Li Lei']
math_scores      = [99, 87, 66, 43, 80, 94]
language_scores  = [85, 91, 75, 90, 63, 95]
economics_scores = [91, 88, 76, 30, 92, 79]
df = pd.DataFrame({"Math":math_scores, "Language":language_scores, "Economy": economics_scores}, index = names)
df = df.drop(columns=['Math', 'Economy'])
df
# Out:
#             Language
# Jim               85
# Jack              91
# Lucy              75
# Lily              90
# Han Meimei        63
# Li Lei            95

# %% [markdown]
# ## <font size=5><span id="15.4"> 15.4 Pandas 文件操作 </span></font>

# %% [markdown]
# #### <center>Pandas可以读取的对象</center>

# %% [markdown]
# <table class="colwidths-given table">
# <colgroup>
# <col style="width: 12%">
# <col style="width: 40%">
# <col style="width: 24%">
# <col style="width: 24%">
# </colgroup>
# <thead>
# <tr class="row-odd"><th class="head"><p>Format Type</p></th>
# <th class="head"><p>Data Description</p></th>
# <th class="head"><p>Reader</p></th>
# <th class="head"><p>Writer</p></th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td><p>text</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/Comma-separated_values">CSV</a></p></td>
# <td><p><a class="reference internal" href="#io-read-csv-table"><span class="std std-ref">read_csv</span></a></p></td>
# <td><p><a class="reference internal" href="#io-store-in-csv"><span class="std std-ref">to_csv</span></a></p></td>
# </tr>
# <tr class="row-odd"><td><p>text</p></td>
# <td><p>Fixed-Width Text File</p></td>
# <td><p><a class="reference internal" href="#io-fwf-reader"><span class="std std-ref">read_fwf</span></a></p></td>
# <td></td>
# </tr>
# <tr class="row-even"><td><p>text</p></td>
# <td><p><a class="reference external" href="https://www.json.org/">JSON</a></p></td>
# <td><p><a class="reference internal" href="#io-json-reader"><span class="std std-ref">read_json</span></a></p></td>
# <td><p><a class="reference internal" href="#io-json-writer"><span class="std std-ref">to_json</span></a></p></td>
# </tr>
# <tr class="row-odd"><td><p>text</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/HTML">HTML</a></p></td>
# <td><p><a class="reference internal" href="#io-read-html"><span class="std std-ref">read_html</span></a></p></td>
# <td><p><a class="reference internal" href="#io-html"><span class="std std-ref">to_html</span></a></p></td>
# </tr>
# <tr class="row-even"><td><p>text</p></td>
# <td><p>Local clipboard</p></td>
# <td><p><a class="reference internal" href="#io-clipboard"><span class="std std-ref">read_clipboard</span></a></p></td>
# <td><p><a class="reference internal" href="#io-clipboard"><span class="std std-ref">to_clipboard</span></a></p></td>
# </tr>
# <tr class="row-odd"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/Microsoft_Excel">MS Excel</a></p></td>
# <td><p><a class="reference internal" href="#io-excel-reader"><span class="std std-ref">read_excel</span></a></p></td>
# <td><p><a class="reference internal" href="#io-excel-writer"><span class="std std-ref">to_excel</span></a></p></td>
# </tr>
# <tr class="row-even"><td><p>binary</p></td>
# <td><p><a class="reference external" href="http://www.opendocumentformat.org">OpenDocument</a></p></td>
# <td><p><a class="reference internal" href="#io-ods"><span class="std std-ref">read_excel</span></a></p></td>
# <td></td>
# </tr>
# <tr class="row-odd"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://support.hdfgroup.org/HDF5/whatishdf5.html">HDF5 Format</a></p></td>
# <td><p><a class="reference internal" href="#io-hdf5"><span class="std std-ref">read_hdf</span></a></p></td>
# <td><p><a class="reference internal" href="#io-hdf5"><span class="std std-ref">to_hdf</span></a></p></td>
# </tr>
# <tr class="row-even"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://github.com/wesm/feather">Feather Format</a></p></td>
# <td><p><a class="reference internal" href="#io-feather"><span class="std std-ref">read_feather</span></a></p></td>
# <td><p><a class="reference internal" href="#io-feather"><span class="std std-ref">to_feather</span></a></p></td>
# </tr>
# <tr class="row-odd"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://parquet.apache.org/">Parquet Format</a></p></td>
# <td><p><a class="reference internal" href="#io-parquet"><span class="std std-ref">read_parquet</span></a></p></td>
# <td><p><a class="reference internal" href="#io-parquet"><span class="std std-ref">to_parquet</span></a></p></td>
# </tr>
# <tr class="row-even"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://orc.apache.org/">ORC Format</a></p></td>
# <td><p><a class="reference internal" href="#io-orc"><span class="std std-ref">read_orc</span></a></p></td>
# <td></td>
# </tr>
# <tr class="row-odd"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://msgpack.org/index.html">Msgpack</a></p></td>
# <td><p><a class="reference internal" href="#io-msgpack"><span class="std std-ref">read_msgpack</span></a></p></td>
# <td><p><a class="reference internal" href="#io-msgpack"><span class="std std-ref">to_msgpack</span></a></p></td>
# </tr>
# <tr class="row-even"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/Stata">Stata</a></p></td>
# <td><p><a class="reference internal" href="#io-stata-reader"><span class="std std-ref">read_stata</span></a></p></td>
# <td><p><a class="reference internal" href="#io-stata-writer"><span class="std std-ref">to_stata</span></a></p></td>
# </tr>
# <tr class="row-odd"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/SAS_(software)">SAS</a></p></td>
# <td><p><a class="reference internal" href="#io-sas-reader"><span class="std std-ref">read_sas</span></a></p></td>
# <td></td>
# </tr>
# <tr class="row-even"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/SPSS">SPSS</a></p></td>
# <td><p><a class="reference internal" href="#io-spss-reader"><span class="std std-ref">read_spss</span></a></p></td>
# <td></td>
# </tr>
# <tr class="row-odd"><td><p>binary</p></td>
# <td><p><a class="reference external" href="https://docs.python.org/3/library/pickle.html">Python Pickle Format</a></p></td>
# <td><p><a class="reference internal" href="#io-pickle"><span class="std std-ref">read_pickle</span></a></p></td>
# <td><p><a class="reference internal" href="#io-pickle"><span class="std std-ref">to_pickle</span></a></p></td>
# </tr>
# <tr class="row-even"><td><p>SQL</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/SQL">SQL</a></p></td>
# <td><p><a class="reference internal" href="#io-sql"><span class="std std-ref">read_sql</span></a></p></td>
# <td><p><a class="reference internal" href="#io-sql"><span class="std std-ref">to_sql</span></a></p></td>
# </tr>
# <tr class="row-odd"><td><p>SQL</p></td>
# <td><p><a class="reference external" href="https://en.wikipedia.org/wiki/BigQuery">Google BigQuery</a></p></td>
# <td><p><a class="reference internal" href="#io-bigquery"><span class="std std-ref">read_gbq</span></a></p></td>
# <td><p><a class="reference internal" href="#io-bigquery"><span class="std std-ref">to_gbq</span></a></p></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### <font size=5><span id="15.4.1"> 15.4.1 csv 文件 </span></font>

# %% [markdown]
# #### 例：奥运会数据分析
# 数据文件：Athletes_summer_games.csv

# %% [markdown]
# #### 奥运会男女运动员年龄分布

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('files/chapter15/Athletes_summer_games.csv')
df
# Out:
#         Unnamed: 0                                Name Sex   Age  \
# 0                0                           A Dijiang   M  24.0
# 1                1                            A Lamusi   M  23.0
# 2                2                 Gunnar Nielsen Aaby   M  24.0
# 3                3                Edgar Lindenau Aabye   M  34.0
# 4               26  Cornelia "Cor" Aalten (-Strannood)   F  18.0
# ...            ...                                 ...  ..   ...
# 237668       15116                   ZWOLINSKA Klaudia   F  22.0
# 237669       15117                        ZYKOVA Yulia   F  25.0
# 237670       15118                   ZYUZINA Ekaterina   F  24.0
# 237671       15119                     ZYZANSKA Sylwia   F  24.0
# 237672       15120                     ZYZANSKA Sylwia   F  24.0
#
#                   Team  NOC        Games  Year  Season         City  \
# 0                China  CHN  1992 Summer  1992  Summer    Barcelona
# ...

# %%
all_athlete_age = df['Age'].dropna().to_list()     # dropna 去除 nan
male_athlete_age = df.loc[df['Sex']=='M']['Age'].dropna().to_list()
female_athlete_age = df.loc[df['Sex']=='F']['Age'].dropna().to_list()

# %%
fig, ax = plt.subplots(figsize = (5, 3))
ax.hist(all_athlete_age, bins= 20)
plt.show()

# %% [markdown]
# #### 历届奥运会男女运动员数量比例

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('files/chapter15/Athletes_summer_games.csv')
years = df['Year'].unique()
years
# Out:
# array([1992, 2012, 1920, 1900, 1932, 1952, 2000, 1996, 1912, 1924, 1948,
#        2008, 2016, 2004, 1984, 1968, 1972, 1988, 1936, 1956, 1960, 1928,
#        1976, 1980, 1964, 1906, 1904, 1908, 1896, 2020])

# %%
rst = np.zeros((year_count, 3))
for i in range(year_count):
    annual_df = df.loc[df['Year']==years[i]]
    annual_df.drop_duplicates('Name')
    total_athlete_count = annual_df['Name'].count()
    total_male_athlete_count = annual_df.loc[annual_df['Sex']=='M']['Name'].count()
    rst[i, 0] = years[i]
    rst[i, 1] = total_male_athlete_count / total_athlete_count
    rst[i, 2] = 1.0 - rst[i, 1]

# %%
# sort
idx = np.argsort(rst[:, 0])
rst = rst[idx]

# %%
fig = plt.figure(figsize = (10, 2))
plt.bar(x = rst[:, 0], height = rst[:, 2], width = 1.5, color = 'r')
plt.bar(x = rst[:, 0], height = rst[:, 1], bottom = rst[:, 2], width = 1.5, color = 'b')
plt.show()

# %% [markdown]
# #### 历届奥运会某代表团优势项目
# 想一想，用什么指标来表示“优势”

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('files/chapter15/Athletes_winter_games.csv')
years = df['Year'].unique()
years = np.sort(years)
NOC = 'CHN'

# %%
# 先尝试一个具体的案例
year = 2008
sports = df.loc[df['Year']==year]['Sport'].unique()
total_sport_count = sports.size
sport = 'Diving'
events = df.loc[(df['Year']==year) & (df['Sport']==sport)]['Event'].unique()
total_event_count = events.size
series = df.loc[(df['Year']==year) & (df['Sport']==sport) & (df['NOC']==NOC) & (df['Medal']=='Gold')]['Event'].drop_duplicates()
NOC_sport_medal_count = series.count()
print(NOC_sport_medal_count, total_event_count)
# Out:
# 7 8

# %%
events
# Out:
# array(["Diving Women's Springboard", "Diving Men's Platform",
#        "Diving Men's Synchronized Platform",
#        "Diving Women's Synchronized Springboard",
#        "Diving Women's Synchronized Platform", "Diving Men's Springboard",
#        "Diving Women's Platform", "Diving Men's Synchronized Springboard"],
#       dtype=object)

# %%
# 再完善整个程序
gold_medal_percentages = {}
for year in years:
    gold_medal_percentages[year] = {}
for year in years:
    sports = df.loc[df['Year']==year]['Sport'].unique()
    for sport in sports:
        events = df.loc[(df['Year']==year) & (df['Sport']==sport)]['Event'].unique()
        total_event_count = events.size
        series = df.loc[(df['Year']==year) & (df['Sport']==sport) & (df['NOC']==NOC) & (df['Medal']=='Gold')]['Event'].drop_duplicates()
        NOC_sport_gold_medal_count = series.count()
        if (NOC_sport_gold_medal_count > 0):
            gold_medal_percentages[year][sport] = NOC_sport_gold_medal_count * 1.0 / total_event_count

# %%
# 至此，gold_medal_percentages 保存了我们所需要的全部信息
# 接下来，通过 stacked bar 的形式进行可视化

# 从第一块金牌的那一届奥运会开始画图
years_after_first_gold = []
for year in gold_medal_percentages.keys():
    for sport in gold_medal_percentages[year].keys():
        if (gold_medal_percentages[year][sport] > 0):
            years_after_first_gold.append(year)
years_after_first_gold = list(set(years_after_first_gold))
years_after_first_gold.sort()
            
# 每届奥运会大项（sport）的数目有差别，为了绘图，需要将每届奥运会的大项统一化
sports = []
for year in years_after_first_gold:
    for sport in gold_medal_percentages[year].keys():
        sports.append(sport)
sports = list(set(sports))

data = [0.0] * len(years_after_first_gold)
for i in range(len(years_after_first_gold)):
    data[i] = [0.0] * (len(sports) + 1)      # year + gold_medal_percentage for each sport
    data[i][0] = years_after_first_gold[i]

for year in years_after_first_gold:
    year_index = years_after_first_gold.index(year)
    for sport in gold_medal_percentages[year].keys():
        sport_index = sports.index(sport)
        data[year_index][sport_index+1] = gold_medal_percentages[year][sport]
        
df = pd.DataFrame(data,columns=["Year"]+sports)
plt.rcParams.update({'font.size': 60})
fig = df.plot(x='Year', kind='bar', stacked=True, title='Gold medal Distr.', legend=False, figsize=(50,30), fontsize=50)
fig.axes.title.set_size(60)
plt.legend(sports, loc='upper left', fontsize=30)
plt.grid()  # 生成网格
plt.show()

# %% [markdown]
# ### <font size=5><span id="15.4.2"> 15.4.2 excel 文件 </span></font>
# #### 注意：可能需要安装 xlrd 模块

# %% [markdown]
# #### （1）读取
# - 语法
# ```python
#     >>> pd.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None,
#                 engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None,
#                 na_values=None, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0,
#                 convert_float=True, **kwds)
# ```
#
#
# - 参数
#     - io —— 字符串、路径、URL等
#     - sheet_name
#     - header —— 用着列标签

# %% [markdown]
# #### （2）写入
# - 语法
# ```python
# >>> df.to_excel(excel_writer, sheet_name='Sheet1', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, startrow=0, startcol=0, engine=None, merge_cells=True, encoding=None, inf_rep='inf', verbose=True, freeze_panes=None)
# ```
#
#
# - 参数
#     - excel_writer —— 字符串、ExcelWriter对象、文件路径等
#     - sheet_name —— 字符串，缺省为 "sheet1"，将包含DataFrame的表的名称。
#     - na_rep : 字符串,默认‘ ’，缺失数据表示方式。
#     - float_format : 字符串,默认None，格式化浮点数的字符串
#     - columns —— 列标记，要编写的列
#     - encoding —— 编码
#     - header : 布尔或字符串列表，默认为Ture。写出列名。如果给定字符串列表，则假定它是列名称的别名。
#     - index :布尔,默认的Ture。写行名（索引）
#     - index_label : 字符串或序列，默认为None。；如果需要，可以使用索引列的列标签。如果没有给出，标题和索引为true，则使用索引名称。如果数据文件使用多索引，则需使用序列。
#     - startrow : 左上角的单元格行来转储数据框
#     - startcol : 左上角的单元格列转储数据帧
#     - engine : 字符串,默认没有；使用写引擎 - 您也可以通过选项io.excel.xlsx.writer，io.excel.xls.writer和io.excel.xlsm.writer进行设置。
#     - merge_cells : 布尔,默认为Ture；编码生成的excel文件。 只有xlwt需要，其他编写者本地支持unicode。
#     - inf_rep : 字符串,默认“正”，无穷大的表示(在Excel中不存在无穷大的本地表示)
#     - freeze_panes : 整数的元组(长度2)，默认为None。指定要冻结的基于1的最底部行和最右边的列

# %% [markdown]
# #### 例：三国人物
# 数据文件：三国志13武将大全.xls

# %%
import pandas as pd
df = pd.read_excel('files\\chapter15\\三国志13武将大全.xls')
df.head(10)
# Out:
#    武将编号   武将 性别  原始统率  原始武力  原始智力  原始政治  四维合计 枪兵适性 骑兵适性  ...  类型 喜好武具 喜好书籍  \
# 0     0  阿会喃  男    65    74    26    33   198    Ｃ    Ｂ  ...  武官    ×    ×
# 1     1   韦昭  男    16    19    65    73   173    Ｃ    Ｃ  ...  文官    ×    ○
# 2     2   伊籍  男    29    24    80    86   219    Ｃ    Ｃ  ...  文官    ×    ○
# 3     3   尹赏  男    51    44    62    66   223    Ｃ    Ｂ  ...  文官    ×    ×
# 4     4  尹大目  男     4     9    33    51    97    Ｃ    Ｃ  ...  文官    ×    ×
# 5     5   尹默  男    26    15    66    77   184    Ｃ    Ｃ  ...  文官    ×    ○
# 6     6   于禁  男    84    77    74    57   292    Ａ    Ａ  ...  武官    ○    ×
# 7     7   于诠  男    64    76    40    39   219    Ａ    Ｃ  ...  武官    ○    ×
# 8     8   卫瓘  男    69    46    79    78   272    Ｃ    Ｃ  ...  武官    ×    ×
# 9     9   袁遗  男    56    40    73    76   245    Ｃ    Ｃ  ...  文官    ×    ○
#
#   喜好宝物  嗜酒  物欲   义理  爱勇   爱才 品级
# 0    ○   ○  贪心   普通  重视   轻视  Ｂ
# 1    ×   ×  无欲   重视  普通   重视  Ｂ
# 2    ×   △  无欲   重视  轻视  最重视  Ａ
# ...

# %%
# 另一种方式
xls = pd.ExcelFile('files\\chapter15\\三国志13武将大全.xls')
df = pd.read_excel(xls)
df.head(10)
# Out:
#    武将编号   武将 性别  原始统率  原始武力  原始智力  原始政治  四维合计 枪兵适性 骑兵适性  ...  类型 喜好武具 喜好书籍  \
# 0     0  阿会喃  男    65    74    26    33   198    Ｃ    Ｂ  ...  武官    ×    ×
# 1     1   韦昭  男    16    19    65    73   173    Ｃ    Ｃ  ...  文官    ×    ○
# 2     2   伊籍  男    29    24    80    86   219    Ｃ    Ｃ  ...  文官    ×    ○
# 3     3   尹赏  男    51    44    62    66   223    Ｃ    Ｂ  ...  文官    ×    ×
# 4     4  尹大目  男     4     9    33    51    97    Ｃ    Ｃ  ...  文官    ×    ×
# 5     5   尹默  男    26    15    66    77   184    Ｃ    Ｃ  ...  文官    ×    ○
# 6     6   于禁  男    84    77    74    57   292    Ａ    Ａ  ...  武官    ○    ×
# 7     7   于诠  男    64    76    40    39   219    Ａ    Ｃ  ...  武官    ○    ×
# 8     8   卫瓘  男    69    46    79    78   272    Ｃ    Ｃ  ...  武官    ×    ×
# 9     9   袁遗  男    56    40    73    76   245    Ｃ    Ｃ  ...  文官    ×    ○
#
#   喜好宝物  嗜酒  物欲   义理  爱勇   爱才 品级
# 0    ○   ○  贪心   普通  重视   轻视  Ｂ
# 1    ×   ×  无欲   重视  普通   重视  Ｂ
# 2    ×   △  无欲   重视  轻视  最重视  Ａ
# ...

# %%
# 统率、武力、智力、政治、综合能力 Top 10
df.sort_values(by='原始智力', ascending=False).head(10)
# Out:
#      武将编号   武将 性别  原始统率  原始武力  原始智力  原始政治  四维合计 枪兵适性 骑兵适性  ...  类型 喜好武具 喜好书籍  \
# 283   283  诸葛亮  男    98    38   100    95   331    Ｓ    Ｃ  ...  文官    ×    ○
# 220   220  司马懿  男    97    63    98    91   349    Ｓ    Ｓ  ...  文官    ×    ○
# 59     59   贾诩  男    88    48    97    85   318    Ａ    Ｂ  ...  文官    ×    ○
# 537   537   庞统  男    86    34    97    85   302    Ｂ    Ｃ  ...  文官    ×    ○
# 241   241   周瑜  男    95    71    96    86   348    Ａ    Ｂ  ...  武官    ×    ○
# 61     61   郭嘉  男    84    15    96    84   279    Ｂ    Ａ  ...  文官    ×    ○
# 250   250   荀彧  男    62    14    95    99   270    Ｃ    Ｃ  ...  文官    ×    ○
# 584   584   陆逊  男    94    69    95    87   345    Ａ    Ｃ  ...  武官    ×    ○
# 255   255   荀攸  男    73    26    94    88   281    Ｂ    Ｂ  ...  文官    ×    ○
# 536   536   法正  男    84    47    94    78   303    Ｃ    Ｃ  ...  文官    ×    ×
#
#     喜好宝物  嗜酒  物欲   义理   爱勇   爱才 品级
# 283    ×   △  无欲  最重视   重视  最重视  Ｓ
# 220    ×   △  普通   普通   普通  最重视  Ｓ
# ...

# %%
df.head(10)
# Out:
#    武将编号   武将 性别  原始统率  原始武力  原始智力  原始政治  四维合计 枪兵适性 骑兵适性  ...  类型 喜好武具 喜好书籍  \
# 0     0  阿会喃  男    65    74    26    33   198    Ｃ    Ｂ  ...  武官    ×    ×
# 1     1   韦昭  男    16    19    65    73   173    Ｃ    Ｃ  ...  文官    ×    ○
# 2     2   伊籍  男    29    24    80    86   219    Ｃ    Ｃ  ...  文官    ×    ○
# 3     3   尹赏  男    51    44    62    66   223    Ｃ    Ｂ  ...  文官    ×    ×
# 4     4  尹大目  男     4     9    33    51    97    Ｃ    Ｃ  ...  文官    ×    ×
# 5     5   尹默  男    26    15    66    77   184    Ｃ    Ｃ  ...  文官    ×    ○
# 6     6   于禁  男    84    77    74    57   292    Ａ    Ａ  ...  武官    ○    ×
# 7     7   于诠  男    64    76    40    39   219    Ａ    Ｃ  ...  武官    ○    ×
# 8     8   卫瓘  男    69    46    79    78   272    Ｃ    Ｃ  ...  武官    ×    ×
# 9     9   袁遗  男    56    40    73    76   245    Ｃ    Ｃ  ...  文官    ×    ○
#
#   喜好宝物  嗜酒  物欲   义理  爱勇   爱才 品级
# 0    ○   ○  贪心   普通  重视   轻视  Ｂ
# 1    ×   ×  无欲   重视  普通   重视  Ｂ
# 2    ×   △  无欲   重视  轻视  最重视  Ａ
# ...

# %%
# 选出男、女武将，分别写入到两个excel文件中
female = df.loc[df['性别']=='女']
female.to_excel('files\\chapter15\\三国志13女性武将大全.xlsx')

# %%
# 设置 ExcelWriter
female = df.loc[df['性别']=='女']
with pd.ExcelWriter('files\\chapter15\\三国志13女性武将大全.xlsx') as writer:
    female.to_excel(writer)

# %%
# 选出男、女武将，分别写入到一个excel文件的2个sheet中
female = df.loc[df['性别']=='女']
male = df.loc[df['性别']=='男']
with pd.ExcelWriter('files/chapter15/三国志13武将大全-分类.xlsx') as writer:
    female.to_excel(writer, sheet_name='女武将', index=False)
    male.to_excel(writer, sheet_name='男武将', index=False)

# %% [markdown]
# ### <font size=5><span id="15.4.3"> 15.4.3 Json 文件 </span></font>

# %% [markdown]
# #### JSON (JavaScript Object Notation) 是一种轻量级的数据交换格式。 易于人阅读和编写。
# - JSON建构于两种结构，一是“名称/值”对的集合（A collection of name/value pairs）。
#     - 不同的语言中，它被理解为对象（object），纪录（record），结构（struct），字典（dictionary），哈希表（hash table），有键列表（keyed list），或者关联数组 （associative array）。
# - 二是值的有序列表（An ordered list of values）。在大部分语言中，它被理解为数组（array）。

# %% [markdown]
# #### （1）读取
# - 语法
#     ```python
#     >>> pd.read_json(json_str)
#     ```

# %%
with open('files\\chapter15\\ranking_full_bundesliga.json','r',encoding='utf-8') as f:
    json_str = f.read()
df = pd.read_json(json_str)
df.tail()
# Out:
#           season  md  position                team  played  won  draw  lost  \
# 34781  2019/2020  34        14       1. FC Cologne      34   10     6    18
# 34782  2019/2020  34        15         FC Augsburg      34    9     9    16
# 34783  2019/2020  34        16       Werder Bremen      34    8     7    19
# 34784  2019/2020  34        17  Fortuna Dusseldorf      34    6    12    16
# 34785  2019/2020  34        18     SC Paderborn 07      34    4     8    22
#
#        gf  ga  gd  points
# 34781  51  69 -18      36
# 34782  45  63 -18      36
# 34783  42  69 -27      31
# 34784  36  67 -31      30
# 34785  37  74 -37      20

# %%
df = df.loc[(df['team']=='Bayern München') | (df['team']=='Bayern Munchen')]
df
# Out:
#           season  md  position            team  played  won  draw  lost  gf  \
# 973    1965/1966   1        14  Bayern München       1    0     0     1   0
# 984    1965/1966   2         7  Bayern München       2    1     0     1   2
# 998    1965/1966   3         3  Bayern München       3    2     0     1   6
# 1014   1965/1966   4         1  Bayern München       4    3     0     1  12
# 1032   1965/1966   5         1  Bayern München       5    4     0     1  14
# ...          ...  ..       ...             ...     ...  ...   ...   ...  ..
# 32860  2016/2017  30         1  Bayern München      30   21     7     2  73
# 32878  2016/2017  31         1  Bayern München      31   22     7     2  79
# 32896  2016/2017  32         1  Bayern München      32   23     7     2  80
# 32914  2016/2017  33         1  Bayern München      33   24     7     2  85
# 32932  2016/2017  34         1  Bayern München      34   25     7     2  89
#
#        ga  gd  points
# 973     1  -1       0
# ...

# %%
season = '1965/1966'
df1 = df.loc[df['season']==season]
df1 = df1.sort_values(by='played', ascending=False)
df1.iloc[0]
# Out:
# season           1965/1966
# md                      34
# position                 3
# team        Bayern München
# played                  34
# won                     20
# draw                     7
# lost                     7
# gf                      71
# ga                      38
# gd                      33
# points                  47
# Name: 1556, dtype: object

# %%
rankings
# Out:
# {}

# %%
start_year = 1963
end_year = 2019
rankings = {}
for i in range(start_year, end_year+1):
    season = str(i) + '/' + str(i+1)
    df1 = df.loc[df['season']==season]
    df1 = df1.sort_values(by='played', ascending=False)
    if (not df1.empty):
        rankings[season] = df1['position'].iloc[0]

for key in rankings.keys():
    print(key, ':', rankings[key])
# Out:
# 1965/1966 : 3
# 1966/1967 : 6
# 1967/1968 : 5
# 1968/1969 : 1
# 1969/1970 : 2
# 1970/1971 : 2
# 1971/1972 : 1
# 1972/1973 : 1
# 1973/1974 : 1
# 1974/1975 : 10
# 1975/1976 : 3
# 1976/1977 : 7
# 1977/1978 : 12
# 1978/1979 : 4
# 1979/1980 : 1
# 1980/1981 : 1
# 1981/1982 : 3
# 1982/1983 : 4
# 1983/1984 : 4
# 1984/1985 : 1
# 1985/1986 : 1
# 1986/1987 : 1
# 1987/1988 : 2
# 1988/1989 : 1
# 1989/1990 : 1
# 1990/1991 : 2
# 1991/1992 : 10
# 1992/1993 : 2
# 1993/1994 : 1
# 1994/1995 : 6
# 1995/1996 : 2
# 1996/1997 : 1
# 1997/1998 : 2
# 1998/1999 : 1
# 1999/2000 : 1
# 2000/2001 : 1
# 2001/2002 : 3
# 2002/2003 : 1
# 2003/2004 : 2
# 2004/2005 : 1
# 2005/2006 : 1
# 2006/2007 : 4
# 2007/2008 : 1
# 2008/2009 : 2
# 2009/2010 : 1
# 2010/2011 : 3
# 2011/2012 : 2
# 2012/2013 : 1
# 2013/2014 : 1
# 2014/2015 : 1
# 2015/2016 : 1
# 2016/2017 : 1

# %% [markdown]
# ## <font size=5><span id="15.5"> 15.5 Pandas 统计分析 </span></font>

# %% [markdown]
# #### 例：2022年世界杯数据分析
# #### 数据文件：Fifa_world_cup_matches.xlsx
# ##### 各队的进球数，失球数，净胜球数，控球率，射门次数，传球，传球成功率，角球，任意球，受迫性失误

# %% [markdown]
# ### <font size=5><span id="15.5.1"> 15.5.1 数据统计 </span></font>

# %%
import pandas as pd

df = pd.read_excel('files\\chapter15\\Fifa_world_cup_matches.xlsx')
df.head()
# Out:
#            team1         team2  possession team1  possession team2  \
# 0          QATAR       ECUADOR              0.42              0.50
# 1        ENGLAND          IRAN              0.72              0.19
# 2        SENEGAL   NETHERLANDS              0.44              0.45
# 3  UNITED STATES         WALES              0.51              0.39
# 4      ARGENTINA  SAUDI ARABIA              0.64              0.24
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                   0.08                      0                      2
# 1                   0.09                      6                      2
# 2                   0.11                      0                      2
# 3                   0.10                      1                      1
# 4                   0.12                      1                      2
#
#         date      hour category  ...  penalties scored team1  \
# 0 2022-11-20  17:00:00  Group A  ...                       0
# ...

# %%
s1 = df['possession team1'][df['number of goals team1'] > df['number of goals team2']]

# %%
s2 = df['possession team2'][df['number of goals team1'] < df['number of goals team2']]

# %%
s = pd.concat([s1, s2])

# %%
s.mean(), s.min(), s.max(), s.median(), s.std()
# Out:
# (0.42714285714285716, 0.14, 0.74, 0.43, 0.1303201186821641)

# %% [markdown]
# ### <font size=5><span id="15.5.2"> 15.5.2 图形可视化 </span></font>

# %%
df.plot(kind='scatter', x='total attempts team1', y='number of goals team1')
# Out:
# <Axes: xlabel='total attempts team1', ylabel='number of goals team1'>

# %%
help(df.plot)
# Out:
# Help on PlotAccessor in module pandas.plotting._core object:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data) -> 'None'
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...
